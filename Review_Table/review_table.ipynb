# %%
#pulling in dependents
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
#pulling in csv data for game reviews
csv_file = "resources/steam_reviews.csv"
reviews_df = pd.read_csv(csv_file)

#display dataframe
reviews_df.head()
# Out:
#   date_posted  funny  helpful  hour_played  is_early_access_review  \
# 0  2019-02-10      2        4          578                   False
# 1  2019-02-10      0        0          184                   False
# 2  2019-02-07      0        0          892                   False
# 3  2018-06-14    126     1086          676                   False
# 4  2017-06-20     85     2139          612                   False
#
#   recommendation                                             review  \
# 0    Recommended  &gt Played as German Reich&gt Declare war on B...
# 1    Recommended                                               yes.
# 2    Recommended  Very good game although a bit overpriced in my...
# 3    Recommended  Out of all the reviews I wrote This one is pro...
# 4    Recommended  Disclaimer I survivor main. I play games for f...
#
#                                          title
# 0  Expansion - Hearts of Iron IV: Man the Guns
# 1  Expansion - Hearts of Iron IV: Man the Guns
# 2  Expansion - Hearts of Iron IV: Man the Guns
# 3                             Dead by Daylight
# 4                             Dead by Daylight

# %%
#convert title csv to dataframe
titles_df = pd.read_csv("resources/titles.csv")

titles_df.head()
# Out:
#    id                    game_title
# 0   0   ACE COMBAT 7: SKIES UNKNOWN
# 1   1         ARK: Survival Evolved
# 2   2                     ASTRONEER
# 3   3  Battlefleet Gothic: Armada 2
# 4   4                    Beat Saber

# %%
#drop columns to leave game title, game review, recommendation, hours played, and date posted
dropped_reviews = reviews_df[['title','review','recommendation','hour_played','date_posted']]

#display dataframe
dropped_reviews.head()
# Out:
#                                          title  \
# 0  Expansion - Hearts of Iron IV: Man the Guns
# 1  Expansion - Hearts of Iron IV: Man the Guns
# 2  Expansion - Hearts of Iron IV: Man the Guns
# 3                             Dead by Daylight
# 4                             Dead by Daylight
#
#                                               review recommendation  \
# 0  &gt Played as German Reich&gt Declare war on B...    Recommended
# 1                                               yes.    Recommended
# 2  Very good game although a bit overpriced in my...    Recommended
# 3  Out of all the reviews I wrote This one is pro...    Recommended
# 4  Disclaimer I survivor main. I play games for f...    Recommended
#
#    hour_played date_posted
# 0          578  2019-02-10
# 1          184  2019-02-10
# 2          892  2019-02-07
# 3          676  2018-06-14
# 4          612  2017-06-20

# %%
#rename columns to match database in SQL
cleaned_reviews = dropped_reviews.rename(columns={'title': 'game_title'})

#display dataframe
cleaned_reviews.head()
# Out:
#                                     game_title  \
# 0  Expansion - Hearts of Iron IV: Man the Guns
# 1  Expansion - Hearts of Iron IV: Man the Guns
# 2  Expansion - Hearts of Iron IV: Man the Guns
# 3                             Dead by Daylight
# 4                             Dead by Daylight
#
#                                               review recommendation  \
# 0  &gt Played as German Reich&gt Declare war on B...    Recommended
# 1                                               yes.    Recommended
# 2  Very good game although a bit overpriced in my...    Recommended
# 3  Out of all the reviews I wrote This one is pro...    Recommended
# 4  Disclaimer I survivor main. I play games for f...    Recommended
#
#    hour_played date_posted
# 0          578  2019-02-10
# 1          184  2019-02-10
# 2          892  2019-02-07
# 3          676  2018-06-14
# 4          612  2017-06-20

# %%
#merge the game title and reviews with inner join on game_title column
merged_df = cleaned_reviews.merge(titles_df, on = "game_title")

merged_df.head()
# Out:
#          game_title                                             review  \
# 0  Dead by Daylight  Out of all the reviews I wrote This one is pro...
# 1  Dead by Daylight  Disclaimer I survivor main. I play games for f...
# 2  Dead by Daylight  ENGLISH After playing for more than two years ...
# 3  Dead by Daylight  Out of all the reviews I wrote This one is pro...
# 4  Dead by Daylight  I have never been told to kill myself more tha...
#
#   recommendation  hour_played date_posted  id
# 0    Recommended          676  2018-06-14   6
# 1    Recommended          612  2017-06-20   6
# 2    Recommended         2694  2016-12-12   6
# 3    Recommended           48  2017-09-17   6
# 4    Recommended           71  2018-12-24   6

# %%
#replace the special characters in game title
merged_df.replace("ACE COMBATâ„¢ 7: SKIES UNKNOWN","ACE COMBAT 7: SKIES UNKNOWN")
merged_df.replace("Rocket LeagueÂ®", "Rocket League")
merged_df.replace("Sid Meier’s Civilization® VI", "Sid Meier's Civilization VI")
merged_df.replace("Sid Meierâ€™s Civilization VI", "Sid Meier's Civilization VI")
merged_df.replace("Tom Clancy's Rainbow Six Siege", "Tom Clancy's Rainbow Six Siege")

dictionary = {"®":'', "™":''}

merged_df.replace(dictionary, regex=True, inplace=True)

# %%
#count the dataframe; reviews column is missing some data -> users not leaving a review
merged_df.count()
# Out:
# game_title        366430
# review            365056
# recommendation    366430
# hour_played       366430
# date_posted       366430
# id                366430
# dtype: int64

# %%
#drop missing reviews  and count again
drop_reviews = merged_df.dropna()

drop_reviews.count()
# Out:
# game_title        365056
# review            365056
# recommendation    365056
# hour_played       365056
# date_posted       365056
# id                365056
# dtype: int64

# %%
#rearrage columns with id first
drop_reviews = drop_reviews[['id','game_title', 'review','recommendation','hour_played','date_posted']]

#rename id column to game_id
final_review = drop_reviews.rename(columns={'id': 'game_id'})

final_review.head()
# Out:
#    game_id        game_title  \
# 0        6  Dead by Daylight
# 1        6  Dead by Daylight
# 2        6  Dead by Daylight
# 3        6  Dead by Daylight
# 4        6  Dead by Daylight
#
#                                               review recommendation  \
# 0  Out of all the reviews I wrote This one is pro...    Recommended
# 1  Disclaimer I survivor main. I play games for f...    Recommended
# 2  ENGLISH After playing for more than two years ...    Recommended
# 3  Out of all the reviews I wrote This one is pro...    Recommended
# 4  I have never been told to kill myself more tha...    Recommended
#
#    hour_played date_posted
# 0          676  2018-06-14
# 1          612  2017-06-20
# 2         2694  2016-12-12
# 3           48  2017-09-17
# 4           71  2018-12-24

# %%
#add an id column 
final_review.reset_index(inplace=True)
final_review = final_review.rename(columns={"index":"id"})

final_review.head()
# Out:
#    id  game_id        game_title  \
# 0   0        6  Dead by Daylight
# 1   1        6  Dead by Daylight
# 2   2        6  Dead by Daylight
# 3   3        6  Dead by Daylight
# 4   4        6  Dead by Daylight
#
#                                               review recommendation  \
# 0  Out of all the reviews I wrote This one is pro...    Recommended
# 1  Disclaimer I survivor main. I play games for f...    Recommended
# 2  ENGLISH After playing for more than two years ...    Recommended
# 3  Out of all the reviews I wrote This one is pro...    Recommended
# 4  I have never been told to kill myself more tha...    Recommended
#
#    hour_played date_posted
# 0          676  2018-06-14
# 1          612  2017-06-20
# 2         2694  2016-12-12
# 3           48  2017-09-17
# 4           71  2018-12-24

# %%
#export table to csv
final_review.to_csv(r'review_table.csv', index = False)

# %%
#connect to SQL Postgres Database
rds_connection_string = "postgres:ChangeMe@localhost:5432/ETL_Project"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#verifying table names in SQL Database
engine.table_names()
# Out:
# ['game_table', 'review_table', 'user_table', 'purchase_table']

# %%
#upload file to SQL Database
final_review.to_sql(name='review_table', con=engine, if_exists='append', index=False)
